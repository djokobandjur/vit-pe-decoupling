# %% [markdown]
# # PE Geometry Probe R32
#
# Seeds: `[456, 789]`
#
# Damage efficiency is evaluated using the actual held-out `rho_rel_geometry`, not nominal target 0.03.

# %%
from pathlib import Path
import json
import os
import subprocess

PACKAGE = Path(r"/home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32")
CONFIG = json.loads(
    (PACKAGE / "CONFIG_R32.json").read_text(encoding="utf-8")
)
SEEDS = [456, 789]

print("PACKAGE:", PACKAGE)
print("OUTPUT:", CONFIG["output_dir"])
print("SEEDS:", SEEDS)
print("RANDOM DIRECTIONS:", CONFIG["random_directions"])
print("DAMAGE EFFICIENCY:",
      CONFIG["damage_efficiency_denominator"])
print("CUDA_VISIBLE_DEVICES:",
      os.environ.get("CUDA_VISIBLE_DEVICES"))

subprocess.run(["nvidia-smi"], check=False)
# Out:
# PACKAGE: /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32
# OUTPUT: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32
# SEEDS: [456, 789]
# RANDOM DIRECTIONS: 32
# DAMAGE EFFICIENCY: actual held-out rho_rel_geometry, not nominal target rho
# CUDA_VISIBLE_DEVICES: None
# Fri Jul 17 22:49:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.86.10              Driver Version: 570.86.10      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H200                    Off |   00000000:43:00.0 Off |                    0 |
# | N/A   30C    P0             77W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# CompletedProcess(args=['nvidia-smi'], returncode=0)

# %%
from pathlib import Path
import json
import os
import subprocess
import sys

PACKAGE = Path(r"/home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32")
CONFIG = json.loads(
    (PACKAGE / "CONFIG_R32.json").read_text(encoding="utf-8")
)

CODE_DIR = Path(CONFIG["code_dir"])
OUTPUT_DIR = Path(CONFIG["output_dir"])
SEEDS = [456, 789]
TAG = "456_789"

env = os.environ.copy()
env["HOME"] = str(Path.home())
env["USER"] = env.get("USER") or "djoko.bandjur.ftnkm"
env["LOGNAME"] = env.get("LOGNAME") or env["USER"]
env["PYTHONUNBUFFERED"] = "1"
env["PYTHONPATH"] = (
    str(CODE_DIR)
    + os.pathsep
    + env.get("PYTHONPATH", "")
)

cache_dir = PACKAGE / "cache" / TAG
cache_dir.mkdir(parents=True, exist_ok=True)

env["XDG_CACHE_HOME"] = str(cache_dir / "xdg")
env["TORCH_HOME"] = str(cache_dir / "torch")


def run_dataset(dataset):
    output_path = (
        OUTPUT_DIR / f"{dataset}_seeds_{TAG}.json"
    )

    common = [
        sys.executable,
        "-u",
        str(CODE_DIR / "mechanistic_geometry_probe.py"),
        "--dataset", dataset,
        "--scripts-dir", str(CODE_DIR),
        "--output-path", str(output_path),
        "--pe-types",
        "learned", "sinusoidal", "rope", "alibi",
        "--seeds", *[str(seed) for seed in SEEDS],
        "--target-rho", "0.03",
        "--random-directions", "32",
        "--gradient-images", "256",
        "--geometry-images", "64",
        "--rho-images", "32",
        "--num-workers", "4",
    ]

    if dataset == "imagenet":
        command = common + [
            "--models-dir", CONFIG["imagenet_models"],
            "--val-dir", CONFIG["imagenet_val"],
            "--gradient-batch", "8",
            "--geometry-batch", "4",
            "--rho-batch", "4",
        ]
    else:
        command = common + [
            "--models-dir", CONFIG["cifar_models"],
            "--val-dir", CONFIG["cifar_val"],
            "--gradient-batch", "64",
            "--geometry-batch", "16",
            "--rho-batch", "16",
        ]

    print("\n" + "=" * 78)
    print("COMMAND:")
    print(" ".join(command))
    print("=" * 78 + "\n")

    subprocess.run(
        command,
        cwd=str(PACKAGE),
        env=env,
        check=True,
    )

    return output_path


imagenet_output = run_dataset("imagenet")
cifar_output = run_dataset("cifar")

print("\nJOB COMPLETE")
print(imagenet_output)
print(cifar_output)
# Out:
# ==============================================================================
# COMMAND:
# /usr/bin/python -u /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code/mechanistic_geometry_probe.py --dataset imagenet --scripts-dir /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code --output-path /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_456_789.json --pe-types learned sinusoidal rope alibi --seeds 456 789 --target-rho 0.03 --random-directions 32 --gradient-images 256 --geometry-images 64 --rho-images 32 --num-workers 4 --models-dir /home/djoko.bandjur.ftnkm/Notebooks/ImageNet100_checkpoints --val-dir /home/djoko.bandjur.ftnkm/datasets/imagenet100/imagenet100_resized/val --gradient-batch 8 --geometry-batch 4 --rho-batch 4
# ==============================================================================
#
# ==============================================================================
# LOCAL HELD-OUT PE GEOMETRY PROBE
# ==============================================================================
# dataset: imagenet
# device: cuda
# output: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_456_789.json
# target rho_rel: 0.03
# gradient images: 256
# geometry images: 64
# rho calibration images: 32
# random directions: 32
#
# [1/8] learned seed=456: already complete
#
# ==============================================================================
# [2/8] LEARNED seed=789
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.000930063 rho=0.030570 err=1.90%
#   [02/33] random_00      radius=0.0200285 rho=0.031528 err=5.09%
#   [03/33] random_01      radius=0.0186774 rho=0.030727 err=2.42%
#   [04/33] random_02      radius=0.0190239 rho=0.030978 err=3.26%
#   [05/33] random_03      radius=0.0182851 rho=0.031532 err=5.11%
#   [06/33] random_04      radius=0.0204742 rho=0.031781 err=5.94%
#   [07/33] random_05      radius=0.0181976 rho=0.030718 err=2.39%
#   [08/33] random_06      radius=0.0189291 rho=0.031212 err=4.04%
#   [09/33] random_07      radius=0.0186593 rho=0.031390 err=4.63%
#   [10/33] random_08      radius=0.0178048 rho=0.030757 err=2.52%
#   [11/33] random_09      radius=0.0182814 rho=0.030838 err=2.79%
#   [12/33] random_10      radius=0.0190784 rho=0.031548 err=5.16%
#   [13/33] random_11      radius=0.0193378 rho=0.031287 err=4.29%
#   [14/33] random_12      radius=0.0194999 rho=0.031019 err=3.40%
#   [15/33] random_13      radius=0.0198442 rho=0.031336 err=4.45%
#   [16/33] random_14      radius=0.0188537 rho=0.031067 err=3.56%
#   [17/33] random_15      radius=0.0188175 rho=0.031405 err=4.68%
#   [18/33] random_16      radius=0.0182142 rho=0.030664 err=2.21%
#   [19/33] random_17      radius=0.0179488 rho=0.031428 err=4.76%
#   [20/33] random_18      radius=0.0193067 rho=0.031090 err=3.63%
#   [21/33] random_19      radius=0.0191191 rho=0.031105 err=3.68%
#   [22/33] random_20      radius=0.0184398 rho=0.031406 err=4.69%
#   [23/33] random_21      radius=0.0189472 rho=0.030498 err=1.66%
#   [24/33] random_22      radius=0.0190646 rho=0.031647 err=5.49%
#   [25/33] random_23      radius=0.0200624 rho=0.031903 err=6.34%
#   [26/33] random_24      radius=0.0196781 rho=0.030866 err=2.89%
#   [27/33] random_25      radius=0.019452 rho=0.031701 err=5.67%
#   [28/33] random_26      radius=0.0177959 rho=0.031066 err=3.55%
#   [29/33] random_27      radius=0.0186283 rho=0.031509 err=5.03%
#   [30/33] random_28      radius=0.0200458 rho=0.031213 err=4.04%
#   [31/33] random_29      radius=0.0189582 rho=0.031037 err=3.46%
#   [32/33] random_30      radius=0.0192818 rho=0.031665 err=5.55%
#   [33/33] random_31      radius=0.0190418 rho=0.031143 err=3.81%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=4
#   geometry batch=004 images=16
#   geometry batch=008 images=32
#   geometry batch=012 images=48
#   geometry batch=016 images=64
#
# SUMMARY alignment task/random-med=0.0004/0.0000 | deltaCE task/random-med=0.02320/-0.00120
#
# ==============================================================================
# [3/8] SINUSOIDAL seed=456
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.0104438 rho=0.030507 err=1.69%
#   [02/33] random_00      radius=0.0353178 rho=0.030359 err=1.20%
#   [03/33] random_01      radius=0.0354666 rho=0.030252 err=0.84%
#   [04/33] random_02      radius=0.0354643 rho=0.030293 err=0.98%
#   [05/33] random_03      radius=0.035679 rho=0.030349 err=1.16%
#   [06/33] random_04      radius=0.0356459 rho=0.030327 err=1.09%
#   [07/33] random_05      radius=0.0355815 rho=0.030445 err=1.48%
#   [08/33] random_06      radius=0.0356037 rho=0.030403 err=1.34%
#   [09/33] random_07      radius=0.0352426 rho=0.030268 err=0.89%
#   [10/33] random_08      radius=0.0353503 rho=0.030270 err=0.90%
#   [11/33] random_09      radius=0.0352525 rho=0.030300 err=1.00%
#   [12/33] random_10      radius=0.03529 rho=0.030345 err=1.15%
#   [13/33] random_11      radius=0.0353175 rho=0.030396 err=1.32%
#   [14/33] random_12      radius=0.0354255 rho=0.030279 err=0.93%
#   [15/33] random_13      radius=0.0357745 rho=0.030372 err=1.24%
#   [16/33] random_14      radius=0.0355595 rho=0.030222 err=0.74%
#   [17/33] random_15      radius=0.0355107 rho=0.030332 err=1.11%
#   [18/33] random_16      radius=0.0356445 rho=0.030271 err=0.90%
#   [19/33] random_17      radius=0.0343309 rho=0.030316 err=1.05%
#   [20/33] random_18      radius=0.0352016 rho=0.030221 err=0.74%
#   [21/33] random_19      radius=0.0354224 rho=0.030366 err=1.22%
#   [22/33] random_20      radius=0.0354492 rho=0.030338 err=1.13%
#   [23/33] random_21      radius=0.0348765 rho=0.030300 err=1.00%
#   [24/33] random_22      radius=0.0349757 rho=0.030324 err=1.08%
#   [25/33] random_23      radius=0.0359858 rho=0.030332 err=1.11%
#   [26/33] random_24      radius=0.035532 rho=0.030299 err=1.00%
#   [27/33] random_25      radius=0.0355778 rho=0.030421 err=1.40%
#   [28/33] random_26      radius=0.035064 rho=0.030311 err=1.04%
#   [29/33] random_27      radius=0.0352616 rho=0.030341 err=1.14%
#   [30/33] random_28      radius=0.0357229 rho=0.030403 err=1.34%
#   [31/33] random_29      radius=0.0350136 rho=0.030335 err=1.12%
#   [32/33] random_30      radius=0.0358542 rho=0.030389 err=1.30%
#   [33/33] random_31      radius=0.0358229 rho=0.030480 err=1.60%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=4
#   geometry batch=004 images=16
#   geometry batch=008 images=32
#   geometry batch=012 images=48
#   geometry batch=016 images=64
#
# SUMMARY alignment task/random-med=0.0005/0.0000 | deltaCE task/random-med=0.03831/-0.00182
#
# ==============================================================================
# [4/8] SINUSOIDAL seed=789
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.00619011 rho=0.028891 err=3.70%
#   [02/33] random_00      radius=0.00680145 rho=0.029713 err=0.96%
#   [03/33] random_01      radius=0.00685296 rho=0.029907 err=0.31%
#   [04/33] random_02      radius=0.00677291 rho=0.030031 err=0.10%
#   [05/33] random_03      radius=0.00644307 rho=0.029608 err=1.31%
#   [06/33] random_04      radius=0.0068225 rho=0.029989 err=0.04%
#   [07/33] random_05      radius=0.0064904 rho=0.031034 err=3.45%
#   [08/33] random_06      radius=0.00661175 rho=0.029914 err=0.29%
#   [09/33] random_07      radius=0.00678202 rho=0.030198 err=0.66%
#   [10/33] random_08      radius=0.00683812 rho=0.029882 err=0.39%
#   [11/33] random_09      radius=0.00688684 rho=0.029779 err=0.74%
#   [12/33] random_10      radius=0.00684826 rho=0.029790 err=0.70%
#   [13/33] random_11      radius=0.00654669 rho=0.030218 err=0.73%
#   [14/33] random_12      radius=0.00673918 rho=0.029834 err=0.55%
#   [15/33] random_13      radius=0.00670564 rho=0.029862 err=0.46%
#   [16/33] random_14      radius=0.00686254 rho=0.030047 err=0.16%
#   [17/33] random_15      radius=0.00692836 rho=0.029999 err=0.00%
#   [18/33] random_16      radius=0.00658779 rho=0.029711 err=0.96%
#   [19/33] random_17      radius=0.00659426 rho=0.029780 err=0.73%
#   [20/33] random_18      radius=0.00691498 rho=0.030051 err=0.17%
#   [21/33] random_19      radius=0.00680071 rho=0.029837 err=0.54%
#   [22/33] random_20      radius=0.00683903 rho=0.029983 err=0.06%
#   [23/33] random_21      radius=0.00688884 rho=0.030135 err=0.45%
#   [24/33] random_22      radius=0.00674623 rho=0.029631 err=1.23%
#   [25/33] random_23      radius=0.00686114 rho=0.029992 err=0.03%
#   [26/33] random_24      radius=0.00637618 rho=0.031613 err=5.38%
#   [27/33] random_25      radius=0.00673814 rho=0.029885 err=0.38%
#   [28/33] random_26      radius=0.00660327 rho=0.029981 err=0.06%
#   [29/33] random_27      radius=0.00634572 rho=0.030271 err=0.90%
#   [30/33] random_28      radius=0.00657891 rho=0.030082 err=0.27%
#   [31/33] random_29      radius=0.00688655 rho=0.029994 err=0.02%
#   [32/33] random_30      radius=0.00690998 rho=0.030031 err=0.10%
#   [33/33] random_31      radius=0.00670022 rho=0.030027 err=0.09%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=4
#   geometry batch=004 images=16
#   geometry batch=008 images=32
#   geometry batch=012 images=48
#   geometry batch=016 images=64
#
# SUMMARY alignment task/random-med=-0.0000/-0.0000 | deltaCE task/random-med=-0.01158/-0.01342
#
# DATASET JOB COMPLETE
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_456_789.json
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_456_789.COMPLETE.json
#
# ==============================================================================
# COMMAND:
# /usr/bin/python -u /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code/mechanistic_geometry_probe.py --dataset cifar --scripts-dir /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code --output-path /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_456_789.json --pe-types learned sinusoidal rope alibi --seeds 456 789 --target-rho 0.03 --random-directions 32 --gradient-images 256 --geometry-images 64 --rho-images 32 --num-workers 4 --models-dir /home/djoko.bandjur.ftnkm/Notebooks/CIFAR100_checkpoints --val-dir /home/djoko.bandjur.ftnkm/datasets/cifar100 --gradient-batch 64 --geometry-batch 16 --rho-batch 16
# ==============================================================================
#
# ==============================================================================
# LOCAL HELD-OUT PE GEOMETRY PROBE
# ==============================================================================
# dataset: cifar
# device: cuda
# output: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds

# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=0.0002/-0.0000 | deltaCE task/random-med=0.01208/0.00009
#
# ==============================================================================
# [5/8] ROPE seed=456
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=64
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.00702888 rho=0.029998 err=0.01%
#   [02/33] random_00      radius=0.032219 rho=0.030007 err=0.02%
#   [03/33] random_01      radius=0.0287951 rho=0.029994 err=0.02%
#   [04/33] random_02      radius=0.0312278 rho=0.029992 err=0.03%
#   [05/33] random_03      radius=0.0294922 rho=0.029993 err=0.02%
#   [06/33] random_04      radius=0.0302016 rho=0.029994 err=0.02%
#   [07/33] random_05      radius=0.0306583 rho=0.030003 err=0.01%
#   [08/33] random_06      radius=0.0295683 rho=0.030003 err=0.01%
#   [09/33] random_07      radius=0.0300527 rho=0.029988 err=0.04%
#   [10/33] random_08      radius=0.0300882 rho=0.029982 err=0.06%
#   [11/33] random_09      radius=0.0295338 rho=0.030008 err=0.03%
#   [12/33] random_10      radius=0.0294819 rho=0.030006 err=0.02%
#   [13/33] random_11      radius=0.0282134 rho=0.029939 err=0.20%
#   [14/33] random_12      radius=0.0275639 rho=0.030005 err=0.02%
#   [15/33] random_13      radius=0.0301286 rho=0.029991 err=0.03%
#   [16/33] random_14      radius=0.032159 rho=0.029987 err=0.04%
#   [17/33] random_15      radius=0.0306364 rho=0.029984 err=0.05%
#   [18/33] random_16      radius=0.0290923 rho=0.029987 err=0.04%
#   [19/33] random_17      radius=0.0298364 rho=0.029988 err=0.04%
#   [20/33] random_18      radius=0.028644 rho=0.030003 err=0.01%
#   [21/33] random_19      radius=0.0306974 rho=0.029998 err=0.01%
#   [22/33] random_20      radius=0.029687 rho=0.029995 err=0.02%
#   [23/33] random_21      radius=0.0298425 rho=0.030026 err=0.09%
#   [24/33] random_22      radius=0.0269785 rho=0.029993 err=0.02%
#   [25/33] random_23      radius=0.0319796 rho=0.029998 err=0.01%
#   [26/33] random_24      radius=0.0294988 rho=0.029994 err=0.02%
#   [27/33] random_25      radius=0.028288 rho=0.029993 err=0.02%
#   [28/33] random_26      radius=0.0307845 rho=0.029977 err=0.08%
#   [29/33] random_27      radius=0.0285761 rho=0.029967 err=0.11%
#   [30/33] random_28      radius=0.0297146 rho=0.029987 err=0.04%
#   [31/33] random_29      radius=0.0306534 rho=0.029979 err=0.07%
#   [32/33] random_30      radius=0.0283526 rho=0.030039 err=0.13%
#   [33/33] random_31      radius=0.0304389 rho=0.029998 err=0.01%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=0.0012/0.0002 | deltaCE task/random-med=0.02397/0.00359
#
# ==============================================================================
# [6/8] ROPE seed=789
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=64
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.0124645 rho=0.030016 err=0.05%
#   [02/33] random_00      radius=0.0299015 rho=0.029998 err=0.01%
#   [03/33] random_01      radius=0.0299508 rho=0.029987 err=0.04%
#   [04/33] random_02      radius=0.032004 rho=0.029990 err=0.03%
#   [05/33] random_03      radius=0.0323011 rho=0.029990 err=0.03%
#   [06/33] random_04      radius=0.0305021 rho=0.029978 err=0.07%
#   [07/33] random_05      radius=0.0312043 rho=0.029988 err=0.04%
#   [08/33] random_06      radius=0.0321965 rho=0.030015 err=0.05%
#   [19/33] random_17      radius=0.00670936 rho=0.029587 err=1.38%
#   [20/33] random_18      radius=0.00662589 rho=0.029491 err=1.70%
#   [21/33] random_19      radius=0.00663201 rho=0.030202 err=0.67%
#   [22/33] random_20      radius=0.00676088 rho=0.029721 err=0.93%
#   [23/33] random_21      radius=0.00682627 rho=0.029984 err=0.05%
#   [24/33] random_22      radius=0.00670706 rho=0.029733 err=0.89%
#   [25/33] random_23      radius=0.00694827 rho=0.029752 err=0.83%
#   [26/33] random_24      radius=0.00687982 rho=0.029674 err=1.09%
#   [27/33] random_25      radius=0.00686556 rho=0.029763 err=0.79%
#   [28/33] random_26      radius=0.00702522 rho=0.029796 err=0.68%
#   [29/33] random_27      radius=0.00677024 rho=0.029815 err=0.62%
#   [30/33] random_28      radius=0.00698035 rho=0.029661 err=1.13%
#   [31/33] random_29      radius=0.00684873 rho=0.029744 err=0.85%
#   [32/33] random_30      radius=0.0070015 rho=0.029674 err=1.09%
#   [33/33] random_31      radius=0.00702336 rho=0.029763 err=0.79%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=0.0002/0.0000 | deltaCE task/random-med=0.03118/0.00862
#
# ==============================================================================
# [8/8] ALIBI seed=789
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=64
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.00657736 rho=0.029539 err=1.54%
#   [02/33] random_00      radius=0.00688943 rho=0.029760 err=0.80%
#   [03/33] random_01      radius=0.00694467 rho=0.029824 err=0.59%
#   [04/33] random_02      radius=0.00694736 rho=0.029751 err=0.83%
#   [05/33] random_03      radius=0.0067556 rho=0.029608 err=1.31%
#   [06/33] random_04      radius=0.00693258 rho=0.029827 err=0.58%
#   [07/33] random_05      radius=0.00690781 rho=0.029836 err=0.55%
#   [08/33] random_06      radius=0.00669228 rho=0.029467 err=1.78%
#   [09/33] random_07      radius=0.00695892 rho=0.029806 err=0.65%
#   [10/33] random_08      radius=0.00680571 rho=0.029675 err=1.08%
#   [11/33] random_09      radius=0.0068988 rho=0.029692 err=1.03%
#   [12/33] random_10      radius=0.00698208 rho=0.029802 err=0.66%
#   [13/33] random_11      radius=0.00693346 rho=0.029772 err=0.76%
#   [14/33] random_12      radius=0.00688528 rho=0.029726 err=0.91%
#   [15/33] random_13      radius=0.00673589 rho=0.029713 err=0.96%
#   [16/33] random_14      radius=0.00676626 rho=0.029626 err=1.25%
#   [17/33] random_15      radius=0.00686387 rho=0.029825 err=0.58%
#   [18/33] random_16      radius=0.00688698 rho=0.029814 err=0.62%
#   [19/33] random_17      radius=0.00687659 rho=0.029837 err=0.54%
#   [20/33] random_18      radius=0.00684397 rho=0.029666 err=1.11%
#   [21/33] random_19      radius=0.00672725 rho=0.029902 err=0.33%
#   [22/33] random_20      radius=0.00676427 rho=0.029676 err=1.08%
#   [23/33] random_21      radius=0.0069284 rho=0.029726 err=0.91%
#   [24/33] random_22      radius=0.00692913 rho=0.029830 err=0.57%
#   [25/33] random_23      radius=0.00654123 rho=0.029474 err=1.75%
#   [26/33] random_24      radius=0.00685542 rho=0.029648 err=1.17%
#   [27/33] random_25      radius=0.00684838 rho=0.029687 err=1.04%
#   [28/33] random_26      radius=0.00691244 rho=0.029754 err=0.82%
#   [29/33] random_27      radius=0.00663978 rho=0.029872 err=0.43%
#   [30/33] random_28      radius=0.00694323 rho=0.029694 err=1.02%
#   [31/33] random_29      radius=0.00682244 rho=0.029715 err=0.95%
#   [32/33] random_30      radius=0.00672402 rho=0.029996 err=0.01%
#   [33/33] random_31      radius=0.006784 rho=0.029684 err=1.05%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=-0.0001/-0.0001 | deltaCE task/random-med=0.03303/0.00281
#
# DATASET JOB COMPLETE
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_456_789.json
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_456_789.COMPLETE.json
#
# JOB COMPLETE
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_456_789.json
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_456_789.json

# %%
from pathlib import Path
import json
import math

PACKAGE = Path(r"/home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32")
CONFIG = json.loads(
    (PACKAGE / "CONFIG_R32.json").read_text(encoding="utf-8")
)

OUTPUT_DIR = Path(CONFIG["output_dir"])
SEEDS = [456, 789]
TAG = "456_789"

EXPECTED_DIRECTION_NAMES = (
    {"task_gradient"}
    | {f"random_{index:02d}" for index in range(32)}
)


def verify_dataset(dataset):
    path = OUTPUT_DIR / f"{dataset}_seeds_{TAG}.json"
    marker = path.with_suffix(".COMPLETE.json")

    if not path.is_file():
        raise FileNotFoundError(path)

    if not marker.is_file():
        raise FileNotFoundError(marker)

    payload = json.loads(path.read_text(encoding="utf-8"))

    for pe_type in ("learned", "sinusoidal", "rope", "alibi"):
        for seed in SEEDS:
            record = payload["results"][pe_type][str(seed)]

            assert record["status"] == "ok", (
                dataset, pe_type, seed, record.get("status")
            )

            directions = record["directions"]

            assert set(directions) == EXPECTED_DIRECTION_NAMES, (
                dataset,
                pe_type,
                seed,
                len(directions),
                sorted(set(directions) - EXPECTED_DIRECTION_NAMES),
                sorted(EXPECTED_DIRECTION_NAMES - set(directions)),
            )

            for direction_name, direction in directions.items():
                heldout = direction["heldout_geometry"]

                rho = float(heldout["rho_rel_geometry"])
                delta_ce = float(heldout["delta_ce"])
                stored_efficiency = float(
                    heldout[
                        "damage_efficiency_delta_ce_per_rho"
                    ]
                )

                assert math.isfinite(rho) and rho > 0, (
                    dataset, pe_type, seed, direction_name, rho
                )

                expected_efficiency = delta_ce / rho

                assert math.isclose(
                    stored_efficiency,
                    expected_efficiency,
                    rel_tol=1e-9,
                    abs_tol=1e-10,
                ), (
                    dataset,
                    pe_type,
                    seed,
                    direction_name,
                    stored_efficiency,
                    expected_efficiency,
                )

    print("VERIFIED:", path)


verify_dataset("imagenet")
verify_dataset("cifar")

print()
print("VERIFIED JOB SEEDS:", SEEDS)
print("Random directions per model: 32")
print("Total directions per model: 33")
print("Damage efficiency denominator: actual held-out rho")
# Out:
# VERIFIED: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_456_789.json
# VERIFIED: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_456_789.json
#
# VERIFIED JOB SEEDS: [456, 789]
# Random directions per model: 32
# Total directions per model: 33
# Damage efficiency denominator: actual held-out rho
