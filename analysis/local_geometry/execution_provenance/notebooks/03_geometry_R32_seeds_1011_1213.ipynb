# %% [markdown]
# # PE Geometry Probe R32
#
# Seeds: `[1011, 1213]`
#
# Damage efficiency is evaluated using the actual held-out `rho_rel_geometry`, not nominal target 0.03.

# %%
from pathlib import Path
import json
import os
import subprocess

PACKAGE = Path(r"/home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32")
CONFIG = json.loads(
    (PACKAGE / "CONFIG_R32.json").read_text(encoding="utf-8")
)
SEEDS = [1011, 1213]

print("PACKAGE:", PACKAGE)
print("OUTPUT:", CONFIG["output_dir"])
print("SEEDS:", SEEDS)
print("RANDOM DIRECTIONS:", CONFIG["random_directions"])
print("DAMAGE EFFICIENCY:",
      CONFIG["damage_efficiency_denominator"])
print("CUDA_VISIBLE_DEVICES:",
      os.environ.get("CUDA_VISIBLE_DEVICES"))

subprocess.run(["nvidia-smi"], check=False)
# Out:
# PACKAGE: /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32
# OUTPUT: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32
# SEEDS: [1011, 1213]
# RANDOM DIRECTIONS: 32
# DAMAGE EFFICIENCY: actual held-out rho_rel_geometry, not nominal target rho
# CUDA_VISIBLE_DEVICES: None
# Fri Jul 17 22:48:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.86.10              Driver Version: 570.86.10      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H200                    Off |   00000000:1B:00.0 Off |                    0 |
# | N/A   29C    P0             79W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# CompletedProcess(args=['nvidia-smi'], returncode=0)

# %%
from pathlib import Path
import json
import os
import subprocess
import sys

PACKAGE = Path(r"/home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32")
CONFIG = json.loads(
    (PACKAGE / "CONFIG_R32.json").read_text(encoding="utf-8")
)

CODE_DIR = Path(CONFIG["code_dir"])
OUTPUT_DIR = Path(CONFIG["output_dir"])
SEEDS = [1011, 1213]
TAG = "1011_1213"

env = os.environ.copy()
env["HOME"] = str(Path.home())
env["USER"] = env.get("USER") or "djoko.bandjur.ftnkm"
env["LOGNAME"] = env.get("LOGNAME") or env["USER"]
env["PYTHONUNBUFFERED"] = "1"
env["PYTHONPATH"] = (
    str(CODE_DIR)
    + os.pathsep
    + env.get("PYTHONPATH", "")
)

cache_dir = PACKAGE / "cache" / TAG
cache_dir.mkdir(parents=True, exist_ok=True)

env["XDG_CACHE_HOME"] = str(cache_dir / "xdg")
env["TORCH_HOME"] = str(cache_dir / "torch")


def run_dataset(dataset):
    output_path = (
        OUTPUT_DIR / f"{dataset}_seeds_{TAG}.json"
    )

    common = [
        sys.executable,
        "-u",
        str(CODE_DIR / "mechanistic_geometry_probe.py"),
        "--dataset", dataset,
        "--scripts-dir", str(CODE_DIR),
        "--output-path", str(output_path),
        "--pe-types",
        "learned", "sinusoidal", "rope", "alibi",
        "--seeds", *[str(seed) for seed in SEEDS],
        "--target-rho", "0.03",
        "--random-directions", "32",
        "--gradient-images", "256",
        "--geometry-images", "64",
        "--rho-images", "32",
        "--num-workers", "4",
    ]

    if dataset == "imagenet":
        command = common + [
            "--models-dir", CONFIG["imagenet_models"],
            "--val-dir", CONFIG["imagenet_val"],
            "--gradient-batch", "8",
            "--geometry-batch", "4",
            "--rho-batch", "4",
        ]
    else:
        command = common + [
            "--models-dir", CONFIG["cifar_models"],
            "--val-dir", CONFIG["cifar_val"],
            "--gradient-batch", "64",
            "--geometry-batch", "16",
            "--rho-batch", "16",
        ]

    print("\n" + "=" * 78)
    print("COMMAND:")
    print(" ".join(command))
    print("=" * 78 + "\n")

    subprocess.run(
        command,
        cwd=str(PACKAGE),
        env=env,
        check=True,
    )

    return output_path


imagenet_output = run_dataset("imagenet")
cifar_output = run_dataset("cifar")

print("\nJOB COMPLETE")
print(imagenet_output)
print(cifar_output)
# Out:
# ==============================================================================
# COMMAND:
# /usr/bin/python -u /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code/mechanistic_geometry_probe.py --dataset imagenet --scripts-dir /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code --output-path /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_1011_1213.json --pe-types learned sinusoidal rope alibi --seeds 1011 1213 --target-rho 0.03 --random-directions 32 --gradient-images 256 --geometry-images 64 --rho-images 32 --num-workers 4 --models-dir /home/djoko.bandjur.ftnkm/Notebooks/ImageNet100_checkpoints --val-dir /home/djoko.bandjur.ftnkm/datasets/imagenet100/imagenet100_resized/val --gradient-batch 8 --geometry-batch 4 --rho-batch 4
# ==============================================================================
#
# ==============================================================================
# LOCAL HELD-OUT PE GEOMETRY PROBE
# ==============================================================================
# dataset: imagenet
# device: cuda
# output: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_1011_1213.json
# target rho_rel: 0.03
# gradient images: 256
# geometry images: 64
# rho calibration images: 32
# random directions: 32
#
#
# ==============================================================================
# [1/8] LEARNED seed=1011
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.000759786 rho=0.031346 err=4.49%
#   [02/33] random_00      radius=0.0198125 rho=0.031192 err=3.97%
#   [03/33] random_01      radius=0.0190739 rho=0.030766 err=2.55%
#   [04/33] random_02      radius=0.0185874 rho=0.030988 err=3.29%
#   [05/33] random_03      radius=0.0201474 rho=0.031156 err=3.85%
#   [06/33] random_04      radius=0.0203407 rho=0.031213 err=4.04%
#   [07/33] random_05      radius=0.0203714 rho=0.030936 err=3.12%
#   [08/33] random_06      radius=0.0192564 rho=0.030868 err=2.89%
#   [09/33] random_07      radius=0.0194412 rho=0.031062 err=3.54%
#   [10/33] random_08      radius=0.0197478 rho=0.031475 err=4.92%
#   [11/33] random_09      radius=0.0195184 rho=0.030242 err=0.81%
#   [12/33] random_10      radius=0.0197162 rho=0.031071 err=3.57%
#   [13/33] random_11      radius=0.0181435 rho=0.030573 err=1.91%
#   [14/33] random_12      radius=0.0192882 rho=0.030924 err=3.08%
#   [15/33] random_13      radius=0.0188864 rho=0.030358 err=1.19%
#   [16/33] random_14      radius=0.0185247 rho=0.031188 err=3.96%
#   [17/33] random_15      radius=0.0183891 rho=0.030760 err=2.53%
#   [18/33] random_16      radius=0.0182788 rho=0.030733 err=2.44%
#   [19/33] random_17      radius=0.0186225 rho=0.030644 err=2.15%
#   [20/33] random_18      radius=0.0194227 rho=0.030950 err=3.17%
#   [21/33] random_19      radius=0.0193272 rho=0.031090 err=3.63%
#   [22/33] random_20      radius=0.0185895 rho=0.030848 err=2.83%
#   [23/33] random_21      radius=0.0194195 rho=0.030698 err=2.33%
#   [24/33] random_22      radius=0.0192186 rho=0.030897 err=2.99%
#   [25/33] random_23      radius=0.0198816 rho=0.031281 err=4.27%
#   [26/33] random_24      radius=0.0196502 rho=0.031256 err=4.19%
#   [27/33] random_25      radius=0.0184881 rho=0.031148 err=3.83%
#   [28/33] random_26      radius=0.0191521 rho=0.031009 err=3.36%
#   [29/33] random_27      radius=0.0208877 rho=0.031288 err=4.29%
#   [30/33] random_28      radius=0.0174325 rho=0.030856 err=2.85%
#   [31/33] random_29      radius=0.0188905 rho=0.030844 err=2.81%
#   [32/33] random_30      radius=0.0205525 rho=0.031087 err=3.62%
#   [33/33] random_31      radius=0.0182171 rho=0.030953 err=3.18%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=4
#   geometry batch=004 images=16
#   geometry batch=008 images=32
#   geometry batch=012 images=48
#   geometry batch=016 images=64
#
# SUMMARY alignment task/random-med=0.0003/0.0001 | deltaCE task/random-med=0.01100/0.00289
#
# ==============================================================================
# [2/8] LEARNED seed=1213
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.000722442 rho=0.031860 err=6.20%
#   [02/33] random_00      radius=0.0195458 rho=0.030422 err=1.41%
#   [03/33] random_01      radius=0.0198172 rho=0.031036 err=3.45%
#   [04/33] random_02      radius=0.020224 rho=0.030779 err=2.60%
#   [05/33] random_03      radius=0.0195714 rho=0.030653 err=2.18%
#   [06/33] random_04      radius=0.0200569 rho=0.030885 err=2.95%
#   [07/33] random_05      radius=0.0199539 rho=0.030849 err=2.83%
#   [08/33] random_06      radius=0.01991 rho=0.030762 err=2.54%
#   [09/33] random_07      radius=0.0208752 rho=0.031237 err=4.12%
#   [10/33] random_08      radius=0.0204072 rho=0.030811 err=2.70%
#   [11/33] random_09      radius=0.019843 rho=0.030839 err=2.80%
#   [12/33] random_10      radius=0.0203086 rho=0.030643 err=2.14%
#   [13/33] random_11      radius=0.0196395 rho=0.030893 err=2.98%
#   [14/33] random_12      radius=0.0205482 rho=0.030649 err=2.16%
#   [15/33] random_13      radius=0.0197419 rho=0.030669 err=2.23%
#   [16/33] random_14      radius=0.0180666 rho=0.030560 err=1.87%
#   [17/33] random_15      radius=0.0195991 rho=0.030622 err=2.07%
#   [18/33] random_16      radius=0.0205675 rho=0.030668 err=2.23%
#   [19/33] random_17      radius=0.0190298 rho=0.030697 err=2.32%
#   [20/33] random_18      radius=0.0188593 rho=0.030633 err=2.11%
#   [21/33] random_19      radius=0.0193921 rho=0.030716 err=2.39%
#   [22/33] random_20      radius=0.0190454 rho=0.030526 err=1.75%
#   [23/33] random_21      radius=0.0195459 rho=0.031232 err=4.11%
#   [24/33] random_22      radius=0.0199524 rho=0.030997 err=3.32%
#   [25/33] random_23      radius=0.0197788 rho=0.030680 err=2.27%
#   [26/33] random_24      radius=0.0196061 rho=0.030784 err=2.61%
#   [27/33] random_25      radius=0.0192439 rho=0.030484 err=1.61%
#   [28/33] random_26      radius=0.020248 rho=0.030670 err=2.23%
#   [29/33] random_27      radius=0.0194323 rho=0.030824 err=2.75%
#   [30/33] random_28      radius=0.020015 rho=0.030727 err=2.42%
#   [31/33] random_29      radius=0.0198695 rho=0.030830 err=2.77%
#   [32/33] random_30      radius=0.0199377 rho=0.030625 err=2.08%
#   [33/33] random_31      radius=0.0199934 rho=0.030690 err=2.30%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=4
#   geometry batch=004 images=16
#   geometry batch=008 images=32
#   geometry batch=012 images=48
#   geometry batch=016 images=64
#
# SUMMARY alignment task/random-med=0.0003/0.0001 | deltaCE task/random-med=0.02258/0.00864
#
# ==============================================================================
# [3/8] SINUSOIDAL seed=1011
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.
ed=1213
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=8
#   gradient batch=008 images=64
#   gradient batch=016 images=128
#   gradient batch=024 images=192
#   gradient batch=032 images=256
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.00636252 rho=0.029458 err=1.81%
#   [02/33] random_00      radius=0.00626285 rho=0.029476 err=1.75%
#   [03/33] random_01      radius=0.00675757 rho=0.029855 err=0.48%
#   [04/33] random_02      radius=0.00659092 rho=0.030500 err=1.67%
#   [05/33] random_03      radius=0.00629175 rho=0.030755 err=2.52%
#   [06/33] random_04      radius=0.00684312 rho=0.029981 err=0.06%
#   [07/33] random_05      radius=0.00640691 rho=0.029415 err=1.95%
#   [08/33] random_06      radius=0.00631567 rho=0.031070 err=3.57%
#   [09/33] random_07      radius=0.0062096 rho=0.029107 err=2.98%
#   [10/33] random_08      radius=0.00662205 rho=0.030175 err=0.58%
#   [11/33] random_09      radius=0.00620495 rho=0.029059 err=3.14%
#   [12/33] random_10      radius=0.00624161 rho=0.029749 err=0.84%
#   [13/33] random_11      radius=0.00594085 rho=0.030362 err=1.21%
#   [14/33] random_12      radius=0.00662953 rho=0.029705 err=0.98%
#   [15/33] random_13      radius=0.00666457 rho=0.029975 err=0.08%
#   [16/33] random_14      radius=0.00645253 rho=0.031234 err=4.11%
#   [17/33] random_15      radius=0.00665742 rho=0.030617 err=2.06%
#   [18/33] random_16      radius=0.00668997 rho=0.029770 err=0.77%
#   [19/33] random_17      radius=0.00661874 rho=0.030054 err=0.18%
#   [20/33] random_18      radius=0.00627686 rho=0.029069 err=3.10%
#   [21/33] random_19      radius=0.00627281 rho=0.031028 err=3.43%
#   [22/33] random_20      radius=0.00664838 rho=0.029779 err=0.74%
#   [23/33] random_21      radius=0.00667302 rho=0.029922 err=0.26%
#   [24/33] random_22      radius=0.00634486 rho=0.030441 err=1.47%
#   [25/33] random_23      radius=0.0065551 rho=0.029848 err=0.51%
#   [26/33] random_24      radius=0.00623992 rho=0.030893 err=2.98%
#   [27/33] random_25      radius=0.00669672 rho=0.029888 err=0.37%
#   [28/33] random_26      radius=0.00684624 rho=0.030000 err=0.00%
#   [29/33] random_27      radius=0.00663633 rho=0.030321 err=1.07%
#   [30/33] random_28      radius=0.0068871 rho=0.030008 err=0.03%
#   [31/33] random_29      radius=0.00665188 rho=0.029935 err=0.22%
#   [32/33] random_30      radius=0.00666493 rho=0.030114 err=0.38%
#   [33/33] random_31      radius=0.00630317 rho=0.029750 err=0.83%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=4
#   geometry batch=004 images=16
#   geometry batch=008 images=32
#   geometry batch=012 images=48
#   geometry batch=016 images=64
#
# SUMMARY alignment task/random-med=0.0001/-0.0000 | deltaCE task/random-med=0.03167/-0.01621
#
# DATASET JOB COMPLETE
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_1011_1213.json
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_1011_1213.COMPLETE.json
#
# ==============================================================================
# COMMAND:
# /usr/bin/python -u /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code/mechanistic_geometry_probe.py --dataset cifar --scripts-dir /home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32/code --output-path /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_1011_1213.json --pe-types learned sinusoidal rope alibi --seeds 1011 1213 --target-rho 0.03 --random-directions 32 --gradient-images 256 --geometry-images 64 --rho-images 32 --num-workers 4 --models-dir /home/djoko.bandjur.ftnkm/Notebooks/CIFAR100_checkpoints --val-dir /home/djoko.bandjur.ftnkm/datasets/cifar100 --gradient-batch 64 --geometry-batch 16 --rho-batch 16
# ==============================================================================
#
# ==============================================================================
# LOCAL HELD-OUT PE GEOMETRY PROBE
# ==============================================================================
# dataset: cifar
# device: cuda
# output: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_1011_1213.json
# target rho_rel: 0.03
# gradient images: 256
# geometry images: 64
# rho calibration images: 32
# random directions: 32
#
#
# ==============================================================================
# [1/8] LEARNED seed=1011
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=64
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0

# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=0.0004/0.0001 | deltaCE task/random-med=0.01970/0.00375
#
# ==============================================================================
# [5/8] ROPE seed=1011
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=64
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.00550292 rho=0.030005 err=0.02%
#   [02/33] random_00      radius=0.0306532 rho=0.029990 err=0.03%
#   [03/33] random_01      radius=0.0305482 rho=0.029988 err=0.04%
#   [04/33] random_02      radius=0.0304981 rho=0.029991 err=0.03%
#   [05/33] random_03      radius=0.0301078 rho=0.029987 err=0.04%
#   [06/33] random_04      radius=0.0283684 rho=0.029997 err=0.01%
#   [07/33] random_05      radius=0.0309266 rho=0.029973 err=0.09%
#   [08/33] random_06      radius=0.0314002 rho=0.029980 err=0.07%
#   [09/33] random_07      radius=0.0302093 rho=0.029993 err=0.02%
#   [10/33] random_08      radius=0.0286624 rho=0.029988 err=0.04%
#   [11/33] random_09      radius=0.0312573 rho=0.029985 err=0.05%
#   [12/33] random_10      radius=0.0289748 rho=0.029988 err=0.04%
#   [13/33] random_11      radius=0.0287616 rho=0.029986 err=0.05%
#   [14/33] random_12      radius=0.0277878 rho=0.029979 err=0.07%
#   [15/33] random_13      radius=0.0310187 rho=0.029992 err=0.03%
#   [16/33] random_14      radius=0.0294947 rho=0.029994 err=0.02%
#   [17/33] random_15      radius=0.0294836 rho=0.029988 err=0.04%
#   [18/33] random_16      radius=0.0307447 rho=0.030002 err=0.01%
#   [19/33] random_17      radius=0.0304987 rho=0.029988 err=0.04%
#   [20/33] random_18      radius=0.0295981 rho=0.029982 err=0.06%
#   [21/33] random_19      radius=0.0306779 rho=0.029993 err=0.02%
#   [22/33] random_20      radius=0.0292414 rho=0.030007 err=0.02%
#   [23/33] random_21      radius=0.0282528 rho=0.029967 err=0.11%
#   [24/33] random_22      radius=0.0293205 rho=0.029993 err=0.02%
#   [25/33] random_23      radius=0.0288076 rho=0.029990 err=0.03%
#   [26/33] random_24      radius=0.0288789 rho=0.029990 err=0.03%
#   [27/33] random_25      radius=0.0294324 rho=0.029987 err=0.04%
#   [28/33] random_26      radius=0.0299172 rho=0.030000 err=0.00%
#   [29/33] random_27      radius=0.0299773 rho=0.030006 err=0.02%
#   [30/33] random_28      radius=0.0280507 rho=0.030003 err=0.01%
#   [31/33] random_29      radius=0.0313596 rho=0.029983 err=0.06%
#   [32/33] random_30      radius=0.0290283 rho=0.029989 err=0.04%
#   [33/33] random_31      radius=0.0286191 rho=0.030002 err=0.01%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=0.0010/-0.0000 | deltaCE task/random-med=0.01920/0.00074
#
# ==============================================================================
# [6/8] ROPE seed=1213
# ==============================================================================
# Computing task-gradient direction...
#   gradient batch=001 images=64
# Calibrating directions to matched rho_rel...
#   [01/33] task_gradient  radius=0.
#   [25/33] random_23      radius=0.00688431 rho=0.029875 err=0.42%
#   [26/33] random_24      radius=0.00695894 rho=0.029824 err=0.59%
#   [27/33] random_25      radius=0.00679521 rho=0.029810 err=0.63%
#   [28/33] random_26      radius=0.00696121 rho=0.029856 err=0.48%
#   [29/33] random_27      radius=0.00697419 rho=0.029809 err=0.64%
#   [30/33] random_28      radius=0.0066967 rho=0.029550 err=1.50%
#   [31/33] random_29      radius=0.0070138 rho=0.029789 err=0.70%
#   [32/33] random_30      radius=0.00691226 rho=0.029838 err=0.54%
#   [33/33] random_31      radius=0.00689401 rho=0.029777 err=0.74%
# Evaluating matched directions on disjoint geometry subset...
#   geometry batch=001 images=16
#   geometry batch=004 images=64
#
# SUMMARY alignment task/random-med=0.0002/-0.0001 | deltaCE task/random-med=0.02647/-0.00052
#
# DATASET JOB COMPLETE
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_1011_1213.json
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_1011_1213.COMPLETE.json
#
# JOB COMPLETE
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_1011_1213.json
# /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_1011_1213.json

# %%
from pathlib import Path
import json
import math

PACKAGE = Path(r"/home/djoko.bandjur.ftnkm/Notebooks/FMLE_PE_GEOMETRY_PROBE_R32")
CONFIG = json.loads(
    (PACKAGE / "CONFIG_R32.json").read_text(encoding="utf-8")
)

OUTPUT_DIR = Path(CONFIG["output_dir"])
SEEDS = [1011, 1213]
TAG = "1011_1213"

EXPECTED_DIRECTION_NAMES = (
    {"task_gradient"}
    | {f"random_{index:02d}" for index in range(32)}
)


def verify_dataset(dataset):
    path = OUTPUT_DIR / f"{dataset}_seeds_{TAG}.json"
    marker = path.with_suffix(".COMPLETE.json")

    if not path.is_file():
        raise FileNotFoundError(path)

    if not marker.is_file():
        raise FileNotFoundError(marker)

    payload = json.loads(path.read_text(encoding="utf-8"))

    for pe_type in ("learned", "sinusoidal", "rope", "alibi"):
        for seed in SEEDS:
            record = payload["results"][pe_type][str(seed)]

            assert record["status"] == "ok", (
                dataset, pe_type, seed, record.get("status")
            )

            directions = record["directions"]

            assert set(directions) == EXPECTED_DIRECTION_NAMES, (
                dataset,
                pe_type,
                seed,
                len(directions),
                sorted(set(directions) - EXPECTED_DIRECTION_NAMES),
                sorted(EXPECTED_DIRECTION_NAMES - set(directions)),
            )

            for direction_name, direction in directions.items():
                heldout = direction["heldout_geometry"]

                rho = float(heldout["rho_rel_geometry"])
                delta_ce = float(heldout["delta_ce"])
                stored_efficiency = float(
                    heldout[
                        "damage_efficiency_delta_ce_per_rho"
                    ]
                )

                assert math.isfinite(rho) and rho > 0, (
                    dataset, pe_type, seed, direction_name, rho
                )

                expected_efficiency = delta_ce / rho

                assert math.isclose(
                    stored_efficiency,
                    expected_efficiency,
                    rel_tol=1e-9,
                    abs_tol=1e-10,
                ), (
                    dataset,
                    pe_type,
                    seed,
                    direction_name,
                    stored_efficiency,
                    expected_efficiency,
                )

    print("VERIFIED:", path)


verify_dataset("imagenet")
verify_dataset("cifar")

print()
print("VERIFIED JOB SEEDS:", SEEDS)
print("Random directions per model: 32")
print("Total directions per model: 33")
print("Damage efficiency denominator: actual held-out rho")
# Out:
# VERIFIED: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/imagenet_seeds_1011_1213.json
# VERIFIED: /home/djoko.bandjur.ftnkm/Notebooks/results/pe_geometry_probe_n6_r32/cifar_seeds_1011_1213.json
#
# VERIFIED JOB SEEDS: [1011, 1213]
# Random directions per model: 32
# Total directions per model: 33
# Damage efficiency denominator: actual held-out rho
